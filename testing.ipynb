# %%
# %load_ext autoreload
# %autoreload 2
# %aimport xls2dict
import pandas as pd
import numpy as np
b=xls2dict.Reader("/tmp/tmphw9d7W/Archana Gavankar_17940262_assignsubmission_file_Answer template FOR CASE 99.xlsx")
df=b.getSheet("Q1")
def isblank(s):
  return [ len(x)==0 for x in s]  
isblank(df.Code)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False]

# %%
import xls2dict
a=xls2dict.Reader("answer.xlsx")
answer=a.dfs[0]
answer
# Out:
#       diag            proc
# 0   I25.11   38500-00[674]
# 1   I25.12   38500-02[676]
# 2    I31.0   38497-00[672]
# 3    T81.2   38600-00[642]
# 4    S25.0   38706-00[693]
# 5    Y60.0   38647-00[644]
# 6   Y92.22   33548-01[707]
# 7   J96.09   38640-00[664]
# 8    F17.1  92514-29[1910]
# 9    I48.9   13882-01[569]
# 10   E87.6  95550-03[1916]
# 11     I10             NaN

# %%
modelAnswer
# Out:
#       Code  Absolute Order Grouping  IntraGroupOrder  GroupOrder
# 0   I25.11             NaN        P              NaN         NaN
# 1   I25.12             NaN      NaN              NaN         NaN
# 2      I10             NaN      NaN              NaN         NaN
# 3    J98.5             NaN      NaN              NaN         NaN
# 4    T81.2             NaN      NaN              NaN         NaN
# 5    S25.0             NaN      NaN              NaN         NaN
# 6    Y60.0             NaN      NaN              NaN         NaN
# 7   Y92.22             NaN      NaN              NaN         NaN
# 8   J96.09             NaN      NaN              NaN         NaN
# 9    I48.9             NaN      NaN              NaN         NaN
# 10   J98.1             NaN      NaN              NaN         NaN
# 11   E87.6             NaN      NaN              NaN         NaN
# 12   F17.1             NaN      NaN              NaN         NaN

# %%
def findGroup( self, answer, group, codes):
    # go through answer one by one, see if the exact group exists, stop when found
    for i in range(0, len(answer) - len(codes) -1):
        if (answer.ix[i:i+len(codes)-1, "diag"] == codes).all():
            #winner
            answer.ix[i:i+len(codes)-1, "Grouping"] = group
            return answer

# %%
a=modelAnswer.Grouping[modelAnswer.Grouping.notnull()].unique()
print a
modelAnswer.Grouping==a[0]

for group in a:
    print modelAnswer.Code[modelAnswer.Grouping==group]

len(answer)
group="A"
codes=modelAnswer.Code[modelAnswer.Grouping==group]
print findGroup('',answer, group, codes)
# Out:
# [u'P' u'A']
# 0    I25.11
# Name: Code, dtype: object
# 4     T81.2
# 5     S25.0
# 6     Y60.0
# 7    Y92.22
# Name: Code, dtype: object
# 3
#       diag            proc Grouping
# 0   I25.11   38500-00[674]        P
# 1   I25.12   38500-02[676]      NaN
# 2    I31.0   38497-00[672]      NaN
# 3    T81.2   38600-00[642]        A
# 4    S25.0   38706-00[693]        A
# 5    Y60.0   38647-00[644]        A
# 6   Y92.22   33548-01[707]        A
# 7   J96.09   38640-00[664]      NaN
# 8    F17.1  92514-29[1910]      NaN
# 9    I48.9   13882-01[569]      NaN
# 10   E87.6  95550-03[1916]      NaN
# 11     I10             NaN      NaN

# %%
from pandas import DataFrame
df1 = DataFrame({'col1':[1,2,3], 'col2':[2,3,4]})
df2 = DataFrame({'col1':[4,2,5], 'col2':[6,3,5]})
df2[~df2.isin(df1).all(1)]
df2[(df2!=df1)].dropna(how='all')
df2[~(df2==df1)].dropna(how='all')

df1
answer

group_codes=answer.ix[1:5, "diag"]
a=answer.ix[2:6, "diag"]
group_codes
group_codes[group_codes.isin(a)]
# Out:
# 2    I31.0
# 3    T81.2
# 4    S25.0
# 5    Y60.0
# Name: diag, dtype: object

# %%
import xls2dict, calculateMark
import pandas as pd
reader=xls2dict.Reader("tests/modelAnswer.xlsx") 
modelAnswer=reader.dfs[0]
marker=calculateMark.Marker(modelAnswer)

print marker.findSlice( pd.Series(["a","b", "c", "d", "e", "f", "g"]), pd.Series(["e", "f"]))
print marker.findSlice( pd.Series(["f", "g"]), pd.Series(["f"]))
print marker.findSlice( pd.Series(["Z", 'a', 'b', 'c', 'd']), pd.Series(["a", "b","d"]))
# Out:
# []
# 0    f
# 1    g
# dtype: object
# 1    a
# 2    b
# 3    c
# 4    d
# dtype: object

# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload

# %%
import xls2dict, calculateMark as cm1, re
import pandas as pd, numpy as np
reader=xls2dict.Reader("tests/modelAnswer.xlsx") 
ma=reader.dfs["Q1"]
submission=xls2dict.Reader("tests/testSubmission.xlsx")
sub=submission.dfs["Q1"]
m=cm1.Marker()
m.prepareAnswer(ma)
sub=m.findGroups(sub)
print ma

print sub
int(re.sub("N","",'1N'))
# Out:
#       Code Grouping  IntraGroupOrder  GroupOrder
# 0   I25.11        P              NaN         NaN
# 1   I25.12      NaN              NaN         NaN
# 2      I10      NaN              NaN         NaN
# 3    J98.5      NaN              NaN         NaN
# 4    T81.2        A                1         NaN
# 5    S25.0        A                2         NaN
# 6    Y60.0        A                3         NaN
# 7   Y92.22        A                4         NaN
# 8   J96.09      NaN              NaN         NaN
# 9    I48.9      NaN              NaN         NaN
# 10   J98.1      NaN              NaN         NaN
# 11   E87.6      NaN              NaN         NaN
# 12   F17.1      NaN              NaN         NaN
#       Code Grouping
# 0   I25.11        P
# 1   I25.12     None
# 2    I31.0     None
# 3    T81.2        A
# 4    S25.0        A
# 5    Y60.0        A
# 6   Y92.22        A
# 7   J96.09     None
# 8    F17.1     None
# 9    I48.9     None
# 10   E87.6     None
# 11     I10     None
# ...

# %%
# %autoreload
import xls2dict, calculateMark as cm1
import pandas as pd, numpy as np
a=pdtaFrame(1,2,3)
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a00a07cdbfe0> in <module>()
#       2 import xls2dict, calculateMark as cm1
#       3 import pandas as pd, numpy as np
# ----> 4 a=DataFrame(1,2,3)
#       5 a
#
# NameError: name 'DataFrame' is not defined
# ERROR: Line magic function `%autoreload` not found.

# %%
import pandas as pd
df=pd.DataFrame(np.random.randn(1,1), index=['A'], columns=['x'])
df.ix[:,"Grouping"]=None
df
# Out:
#           x Grouping
# A  0.280259     None
